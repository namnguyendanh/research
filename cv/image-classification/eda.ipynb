# %%
import cv2

# %%
import numpy as np

np.random.randint(-10, 10)

# %%
img = cv2.imread("midu.jpg", 0)

# %%
img

# %%
cv2.imshow("frame", img)
# Out:
# QObject::moveToThread: Current thread (0x55f775f49690) is not the object's thread (0x55f77635e930).
# Cannot move to target thread (0x55f775f49690)
#
# QObject::moveToThread: Current thread (0x55f775f49690) is not the object's thread (0x55f77635e930).
# Cannot move to target thread (0x55f775f49690)
#
# QObject::moveToThread: Current thread (0x55f775f49690) is not the object's thread (0x55f77635e930).
# Cannot move to target thread (0x55f775f49690)
#
# QObject::moveToThread: Current thread (0x55f775f49690) is not the object's thread (0x55f77635e930).
# Cannot move to target thread (0x55f775f49690)
#
# QObject::moveToThread: Current thread (0x55f775f49690) is not the object's thread (0x55f77635e930).
# Cannot move to target thread (0x55f775f49690)
#
# QObject::moveToThread: Current thread (0x55f775f49690) is not the object's thread (0x55f77635e930).
# Cannot move to target thread (0x55f775f49690)
#
# ...
